# %% [markdown]
# # Predicting Loan Default Data Transformation

# %% [markdown]
# Ideas:
#
#     - Looking at that data there are useful columns and useless columns that we need to eliminate
#     - Also there are columns that can be combined to bring about useful metrics
#     - Combine these
#     - Feed into a neural network
#     - Use the model generated to predict the risk of rending
#     - Submit to Zindi

# %% [markdown]
# ## Import Data into pandas dataframes

# %%
# %ls #check where we are in the directory
# Out:
#  Volume in drive C is Windows8_OS
#  Volume Serial Number is 6A7D-91D2
#
#  Directory of C:\Users\Njoroge Wa Chege\Desktop\Zindi Challenges\Predicting Loan Defaults
#
# 05/15/2019  05:08 PM    <DIR>          .
# 05/15/2019  05:08 PM    <DIR>          ..
# 05/15/2019  04:48 PM    <DIR>          .ipynb_checkpoints
# 05/15/2019  05:07 PM    <DIR>          data
# 05/15/2019  04:40 PM    <DIR>          dtransformation
# 05/15/2019  05:08 PM             3,664 Predicting Loan Default Data Transformation.ipynb
#                1 File(s)          3,664 bytes
#                5 Dir(s)  113,502,003,200 bytes free

# %%
import glob
import pandas as pd

glob.glob('C:/Users/Njoroge Wa Chege/Desktop/Zindi Challenges/Predicting Loan Defaults/data/**/*.csv') #returns List[str]
# Out:
# ['C:/Users/Njoroge Wa Chege/Desktop/Zindi Challenges/Predicting Loan Defaults/data\\Sample Submission\\SampleSubmission.csv',
#  'C:/Users/Njoroge Wa Chege/Desktop/Zindi Challenges/Predicting Loan Defaults/data\\testdata\\testdemographics.csv',
#  'C:/Users/Njoroge Wa Chege/Desktop/Zindi Challenges/Predicting Loan Defaults/data\\testdata\\testperf.csv',
#  'C:/Users/Njoroge Wa Chege/Desktop/Zindi Challenges/Predicting Loan Defaults/data\\testdata\\testprevloans.csv',
#  'C:/Users/Njoroge Wa Chege/Desktop/Zindi Challenges/Predicting Loan Defaults/data\\traindata\\traindemographics.csv',
#  'C:/Users/Njoroge Wa Chege/Desktop/Zindi Challenges/Predicting Loan Defaults/data\\traindata\\trainperf.csv',
#  'C:/Users/Njoroge Wa Chege/Desktop/Zindi Challenges/Predicting Loan Defaults/data\\traindata\\trainprevloans.csv']

# %%
#joining all the files together to one excel sheet

df = pd.concat([pd.read_csv(f) for f in glob.glob('C:/Users/Njoroge Wa Chege/Desktop/Zindi Challenges/Predicting Loan Defaults/data/**/*.csv')], ignore_index = True, sort=False)

# %%
df
# Out:
#                              customerid                   birthdate  \
# 0      8a858f305c8dd672015c93b1db645db4  1976-08-28 00:00:00.000000
# 1      8a858f085a477386015a47fb049e49ca  1978-06-23 00:00:00.000000
# 2      8a858e6f5cd5e874015cd6f5634c39ad  1984-04-04 00:00:00.000000
# 3      8a858e9d5bfd7037015bfdab79f61305  1983-05-28 00:00:00.000000
# 4      8a858fde56eb02280156eb6dafc128ac  1982-03-29 00:00:00.000000
# 5      8a858e695775665c015779a1a5cc1192  1988-11-19 00:00:00.000000
# 6      8a858e225c404292015c4e2b42c67bbe  1986-05-27 00:00:00.000000
# 7      8a858fcf5b39c3ba015b3d9f215c3922  1978-06-11 00:00:00.000000
# 8      8a858edd5c8348c4015c8452bc364cd7  1982-02-06 00:00:00.000000
# 9      8a858ef25c8393f8015c86783932595b  1991-02-09 00:00:00.000000
# 10     8a858edc5ceea2e6015ceea77c5c0300  1987-10-20 00:00:00.000000
# 11     8a858e5856b7840c0156bb256d6e0e6a  1991-01-11 00:00:00.000000
# 12     8a858e8b5bc9e7e6015bcd7b7ee305b9  1983-12-25 00:00:00.000000
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                              customerid                   birthdate  \
# 0      8a858f305c8dd672015c93b1db645db4  1976-08-28 00:00:00.000000
# 1      8a858f085a477386015a47fb049e49ca  1978-06-23 00:00:00.000000
# 2      8a858e6f5cd5e874015cd6f5634c39ad  1984-04-04 00:00:00.000000
# 3      8a858e9d5bfd7037015bfdab79f61305  1983-05-28 00:00:00.000000
# 4      8a858fde56eb02280156eb6dafc128ac  1982-03-29 00:00:00.000000
# 5      8a858e695775665c015779a1a5cc1192  1988-11-19 00:00:00.000000
# 6      8a858e225c404292015c4e2b42c67bbe  1986-05-27 00:00:00.000000
# 7      8a858fcf5b39c3ba015b3d9f215c3922  1978-06-11 00:00:00.000000
# 8      8a858edd5c8348c4015c8452bc364cd7  1982-02-06 00:00:00.000000
# 9      8a858ef25c8393f8015c86783932595b  1991-02-09 00:00:00.000000
# 10     8a858edc5ceea2e6015ceea77c5c0300  1987-10-20 00:00:00.000000
# 11     8a858e5856b7840c0156bb256d6e0e6a  1991-01-11 00:00:00.000000
# ...
